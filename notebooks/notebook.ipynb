# %%
# !rm -rf SteLA_Project
# !git clone --recurse-submodules https://github.com/the-tuning-machine/SteLA_Project.git
# %cd SteLA_Project
# !uv sync

# %%
import torch

torch.cuda.is_available()

# %%
# !uv run python scripts/benchmark.py

# %%
import glob

from IPython.display import Image, display

for img in sorted(glob.glob("benchmark_*.png")):
    print(img)
    display(Image(filename=img))

# %%
import base64
import glob

from IPython.display import HTML, display

for img in sorted(glob.glob("benchmark_*.png")):
    with open(img, "rb") as f:
        b64 = base64.b64encode(f.read()).decode()
    display(HTML(f'<a href="data:image/png;base64,{b64}" download="{img}">Download {img}</a>'))

# %%
# !pip install --force-reinstall --no-cache-dir expressivity --python $(which python)

# %%
# !MPLBACKEND=agg uv run python scripts/main.py

# %%
# !uv pip show expressivity
